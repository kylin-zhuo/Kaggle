# %%
# encoding=utf-8

from __future__ import print_function

import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./MNIST_data", one_hot=True)
# Out:
# Extracting ./MNIST_data/train-images-idx3-ubyte.gz
# Extracting ./MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ./MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ./MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Import packages
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import tensorflow as tf
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
from cnn_utils import *
import time
from cnn_utils import *

# %%
X_new = load_predict_data()

# %%
i = 2524

# %%
df = pd.read_csv('res.csv')

# %%
i = 26140

# %%
i += 20
s = []
for j in range(20):
    s.append(str(df.Label.iloc[i+j]))
print(",".join(s[:10]))
print(",".join(s[10:]))
fig = plt.figure(figsize=(12,4))
for k in range(20):
    a = fig.add_subplot(2,10,k+1)
    plt.imshow(X_new[i+k][:,:,0])
    a.set_title("Pic " + str(i+k+1))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1572-6bc41394faed> in <module>()
#       2 s = []
#       3 for j in range(20):
# ----> 4     s.append(str(df.Label.iloc[i+j]))
#       5 print(",".join(s[:10]))
#       6 print(",".join(s[10:]))
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1310             return self._getitem_tuple(key)
#    1311         else:
# -> 1312             return self._getitem_axis(key, axis=0)
#    1313
#    1314     def _getitem_axis(self, key, axis=0):
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1626
#    1627                 # validate the location
# -> 1628                 self._is_valid_integer(key, axis)
#    1629
#    1630             return self._get_loc(key, axis=axis)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py in _is_valid_integer(self, key, axis)
#    1540         l = len(ax)
#    1541         if key >= l or key < -l:
# -> 1542             raise IndexError("single positional indexer is out-of-bounds")
#    1543         return True
#    1544
#
# IndexError: single positional indexer is out-of-bounds

# %%
# Parameters
learning_rate = 0.001
training_iters = 128*10*300 
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)


# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')

# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

saver = tf.train.Saver()  ##保存的API
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")
    print("save model")
    save_path = saver.save(sess,"./Test_MNIST_model.ckpt")  #保存模型
    print("save model:{0} Finished".format(save_path))

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.}))
# Out:
# Iter 1280, Minibatch Loss= 27300.804688, Training Accuracy= 0.18750
# Iter 2560, Minibatch Loss= 12153.054688, Training Accuracy= 0.50781
# Iter 3840, Minibatch Loss= 5144.216797, Training Accuracy= 0.72656
# Iter 5120, Minibatch Loss= 4931.408203, Training Accuracy= 0.71875
# Iter 6400, Minibatch Loss= 3426.885498, Training Accuracy= 0.80469
# Iter 7680, Minibatch Loss= 2885.349121, Training Accuracy= 0.82812
# Iter 8960, Minibatch Loss= 2825.411377, Training Accuracy= 0.82812
# Iter 10240, Minibatch Loss= 2133.519043, Training Accuracy= 0.82812
# Iter 11520, Minibatch Loss= 3430.996094, Training Accuracy= 0.82812
# Iter 12800, Minibatch Loss= 2843.562988, Training Accuracy= 0.86719
# Iter 14080, Minibatch Loss= 2762.147217, Training Accuracy= 0.89844
# Iter 15360, Minibatch Loss= 1755.564209, Training Accuracy= 0.89844
# Iter 16640, Minibatch Loss= 1379.789917, Training Accuracy= 0.89844
# Iter 17920, Minibatch Loss= 2039.731445, Training Accuracy= 0.87500
# Iter 19200, Minibatch Loss= 2695.535645, Training Accuracy= 0.89844
# Iter 20480, Minibatch Loss= 1002.286438, Training Accuracy= 0.93750
# Iter 21760, Minibatch Loss= 1133.189819, Training Accuracy= 0.92969
# Iter 23040, Minibatch Loss= 493.083191, Training Accuracy= 0.94531
# Iter 24320, Minibatch Loss= 935.236267, Training Accuracy= 0.92188
# Iter 25600, Minibatch Loss= 1231.757812, Training Accuracy= 0.90625
# Iter 26880, Minibatch Loss= 533.103943, Training Accuracy= 0.92188
# Iter 28160, Minibatch Loss= 746.250305, Training Accuracy= 0.92969
# Iter 29440, Minibatch Loss= 737.346924, Training Accuracy= 0.93750
# Iter 30720, Minibatch Loss= 928.431702, Training Accuracy= 0.92969
# Iter 32000, Minibatch Loss= 325.940063, Training Accuracy= 0.94531
# Iter 33280, Minibatch Loss= 984.144897, Training Accuracy= 0.94531
# Iter 34560, Minibatch Loss= 956.997009, Training Accuracy= 0.94531
# Iter 35840, Minibatch Loss= 755.057007, Training Accuracy= 0.93750
# Iter 37120, Minibatch Loss= 964.317505, Training Accuracy= 0.94531
# Iter 38400, Minibatch Loss= 684.637451, Training Accuracy= 0.94531
# Iter 39680, Minibatch Loss= 981.274048, Training Accuracy= 0.94531
# Iter 40960, Minibatch Loss= 1502.846436, Training Accuracy= 0.90625
# Iter 42240, Minibatch Loss= 1231.172119, Training Accuracy= 0.90625
# Iter 43520, Minibatch Loss= 335.883636, Training Accuracy= 0.96094
# Iter 44800, Minibatch Loss= 764.425293, Training Accuracy= 0.93750
# Iter 46080, Minibatch Loss= 411.948242, Training Accuracy= 0.95312
# Iter 47360, Minibatch Loss= 1166.826660, Training Accuracy= 0.91406
# Iter 48640, Minibatch Loss= 725.200012, Training Accuracy= 0.95312
# Iter 49920, Minibatch Loss= 174.541443, Training Accuracy= 0.97656
# Iter 51200, Minibatch Loss= 299.190063, Training Accuracy= 0.96875
# Iter 52480, Minibatch Loss= 1113.141846, Training Accuracy= 0.92188
# Iter 53760, Minibatch Loss= 728.045532, Training Accuracy= 0.96094
# Iter 55040, Minibatch Loss= 485.028076, Training Accuracy= 0.96094
# Iter 56320, Minibatch Loss= 1414.266235, Training Accuracy= 0.93750
# Iter 57600, Minibatch Loss= 542.500305, Training Accuracy= 0.96094
# Iter 58880, Minibatch Loss= 173.393951, Training Accuracy= 0.96875
# Iter 60160, Minibatch Loss= 612.645447, Training Accuracy= 0.96875
# Iter 61440, Minibatch Loss= 580.636841, Training Accuracy= 0.96094
# Iter 62720, Minibatch Loss= 596.944458, Training Accuracy= 0.96094
# Iter 64000, Minibatch Loss= 462.676392, Training Accuracy= 0.96094
# Iter 65280, Minibatch Loss= 217.635986, Training Accuracy= 0.97656
# Iter 66560, Minibatch Loss= 388.328400, Training Accuracy= 0.96094
# Iter 67840, Minibatch Loss= 643.358704, Training Accuracy= 0.92188
# Iter 69120, Minibatch Loss= 438.127411, Training Accuracy= 0.96094
# Iter 70400, Minibatch Loss= 195.740509, Training Accuracy= 0.95312
# Iter 71680, Minibatch Loss= 515.291138, Training Accuracy= 0.96094
# Iter 72960, Minibatch Loss= 246.024048, Training Accuracy= 0.96094
# Iter 74240, Minibatch Loss= 647.092163, Training Accuracy= 0.94531
# Iter 75520, Minibatch Loss= 113.130989, Training Accuracy= 0.96094
# Iter 76800, Minibatch Loss= 816.834717, Training Accuracy= 0.94531
# Iter 78080, Minibatch Loss= 187.880722, Training Accuracy= 0.98438
# Iter 79360, Minibatch Loss= 408.002594, Training Accuracy= 0.96094
# Iter 80640, Minibatch Loss= 112.363693, Training Accuracy= 0.96875
# Iter 81920, Minibatch Loss= 385.838379, Training Accuracy= 0.96875
# Iter 83200, Minibatch Loss= 75.750092, Training Accuracy= 0.98438
# Iter 84480, Minibatch Loss= 107.160309, Training Accuracy= 0.98438
# Iter 85760, Minibatch Loss= 213.730255, Training Accuracy= 0.97656
# Iter 87040, Minibatch Loss= 271.923584, Training Accuracy= 0.96094
# Iter 88320, Minibatch Loss= 146.252075, Training Accuracy= 0.96875
# Iter 89600, Minibatch Loss= 113.376465, Training Accuracy= 0.97656
# Iter 90880, Minibatch Loss= 48.854439, Training Accuracy= 0.98438
# Iter 92160, Minibatch Loss= 222.462143, Training Accuracy= 0.96875
# Iter 93440, Minibatch Loss= 94.860992, Training Accuracy= 0.98438
# Iter 94720, Minibatch Loss= 240.776077, Training Accuracy= 0.95312
# Iter 96000, Minibatch Loss= 507.107788, Training Accuracy= 0.95312
# Iter 97280, Minibatch Loss= 126.198517, Training Accuracy= 0.99219
# Iter 98560, Minibatch Loss= 125.833313, Training Accuracy= 0.97656
# Iter 99840, Minibatch Loss= 464.668610, Training Accuracy= 0.96875
# Iter 101120, Minibatch Loss= 463.880798, Training Accuracy= 0.95312
# Iter 102400, Minibatch Loss= 154.757660, Training Accuracy= 0.97656
# Iter 103680, Minibatch Loss= 195.114716, Training Accuracy= 0.97656
# Iter 104960, Minibatch Loss= 433.278107, Training Accuracy= 0.94531
# Iter 106240, Minibatch Loss= 292.174255, Training Accuracy= 0.96875
# Iter 107520, Minibatch Loss= 153.386978, Training Accuracy= 0.95312
# Iter 108800, Minibatch Loss= 322.117035, Training Accuracy= 0.96094
# Iter 110080, Minibatch Loss= 164.261566, Training Accuracy= 0.97656
# Iter 111360, Minibatch Loss= 247.435669, Training Accuracy= 0.96875
# Iter 112640, Minibatch Loss= 119.036957, Training Accuracy= 0.98438
# Iter 113920, Minibatch Loss= 253.311386, Training Accuracy= 0.97656
# Iter 115200, Minibatch Loss= 275.317932, Training Accuracy= 0.96875
# Iter 116480, Minibatch Loss= 24.068466, Training Accuracy= 0.97656
# Iter 117760, Minibatch Loss= 112.234253, Training Accuracy= 0.98438
# Iter 119040, Minibatch Loss= 241.814087, Training Accuracy= 0.96875
# Iter 120320, Minibatch Loss= 434.652618, Training Accuracy= 0.95312
# Iter 121600, Minibatch Loss= 258.905029, Training Accuracy= 0.96875
# Iter 122880, Minibatch Loss= 252.653107, Training Accuracy= 0.97656
# Iter 124160, Minibatch Loss= 377.355652, Training Accuracy= 0.98438
# Iter 125440, Minibatch Loss= 446.657318, Training Accuracy= 0.97656
# Iter 126720, Minibatch Loss= 582.834167, Training Accuracy= 0.96875
# Iter 128000, Minibatch Loss= 54.277710, Training Accuracy= 0.96875
# Iter 129280, Minibatch Loss= 328.925262, Training Accuracy= 0.96875
# Iter 130560, Minibatch Loss= 364.027832, Training Accuracy= 0.95312
# Iter 131840, Minibatch Loss= 132.407898, Training Accuracy= 0.98438
# Iter 133120, Minibatch Loss= 371.629730, Training Accuracy= 0.97656
# Iter 134400, Minibatch Loss= 292.896667, Training Accuracy= 0.96094
# Iter 135680, Minibatch Loss= 44.554733, Training Accuracy= 0.99219
# Iter 136960, Minibatch Loss= 456.767883, Training Accuracy= 0.94531
# Iter 138240, Minibatch Loss= 123.687164, Training Accuracy= 0.99219
# Iter 139520, Minibatch Loss= 106.403229, Training Accuracy= 0.99219
# Iter 140800, Minibatch Loss= 132.848984, Training Accuracy= 0.97656
# Iter 142080, Minibatch Loss= 97.767670, Training Accuracy= 0.97656
# Iter 143360, Minibatch Loss= 245.417603, Training Accuracy= 0.96875
# Iter 144640, Minibatch Loss= 63.332687, Training Accuracy= 0.98438
# Iter 145920, Minibatch Loss= 125.761566, Training Accuracy= 0.98438
# Iter 147200, Minibatch Loss= 205.035461, Training Accuracy= 0.97656
# Iter 148480, Minibatch Loss= 137.294800, Training Accuracy= 0.97656
# Iter 149760, Minibatch Loss= 198.947952, Training Accuracy= 0.97656
# Iter 151040, Minibatch Loss= 370.018250, Training Accuracy= 0.95312
# Iter 152320, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 153600, Minibatch Loss= 156.831238, Training Accuracy= 0.97656
# Iter 154880, Minibatch Loss= 159.232040, Training Accuracy= 0.98438
# Iter 156160, Minibatch Loss= 83.856964, Training Accuracy= 0.98438
# Iter 157440, Minibatch Loss= 102.363213, Training Accuracy= 0.98438
# Iter 158720, Minibatch Loss= 468.670166, Training Accuracy= 0.96094
# Iter 160000, Minibatch Loss= 153.499512, Training Accuracy= 0.98438
# Iter 161280, Minibatch Loss= 34.422844, Training Accuracy= 0.97656
# Iter 162560, Minibatch Loss= 142.162689, Training Accuracy= 0.97656
# Iter 163840, Minibatch Loss= 131.709686, Training Accuracy= 0.98438
# Iter 165120, Minibatch Loss= 175.794937, Training Accuracy= 0.96094
# Iter 166400, Minibatch Loss= 41.611435, Training Accuracy= 0.99219
# Iter 167680, Minibatch Loss= 166.174423, Training Accuracy= 0.96875
# Iter 168960, Minibatch Loss= 78.586533, Training Accuracy= 0.99219
# Iter 170240, Minibatch Loss= 51.447678, Training Accuracy= 0.99219
# Iter 171520, Minibatch Loss= 50.152512, Training Accuracy= 0.97656
# Iter 172800, Minibatch Loss= 251.416183, Training Accuracy= 0.98438
# Iter 174080, Minibatch Loss= 110.177673, Training Accuracy= 0.96875
# Iter 175360, Minibatch Loss= 169.521088, Training Accuracy= 0.97656
# Iter 176640, Minibatch Loss= 371.818085, Training Accuracy= 0.95312
# Iter 177920, Minibatch Loss= 31.285591, Training Accuracy= 0.98438
# Iter 179200, Minibatch Loss= 180.550293, Training Accuracy= 0.95312
# Iter 180480, Minibatch Loss= 69.565048, Training Accuracy= 0.97656
# Iter 181760, Minibatch Loss= 126.165573, Training Accuracy= 0.98438
# Iter 183040, Minibatch Loss= 300.230530, Training Accuracy= 0.94531
# Iter 184320, Minibatch Loss= 283.142609, Training Accuracy= 0.96094
# Iter 185600, Minibatch Loss= 82.495132, Training Accuracy= 0.97656
# Iter 186880, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 188160, Minibatch Loss= 90.607071, Training Accuracy= 0.99219
# Iter 189440, Minibatch Loss= 72.808014, Training Accuracy= 0.97656
# Iter 190720, Minibatch Loss= 40.681000, Training Accuracy= 0.99219
# Iter 192000, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 193280, Minibatch Loss= 43.006882, Training Accuracy= 0.98438
# Iter 194560, Minibatch Loss= 171.613358, Training Accuracy= 0.98438
# Iter 195840, Minibatch Loss= 117.780533, Training Accuracy= 0.97656
# Iter 197120, Minibatch Loss= 363.344055, Training Accuracy= 0.94531
# Iter 198400, Minibatch Loss= 141.974426, Training Accuracy= 0.98438
# Iter 199680, Minibatch Loss= 110.192780, Training Accuracy= 0.97656
# Iter 200960, Minibatch Loss= 60.216473, Training Accuracy= 0.97656
# Iter 202240, Minibatch Loss= 149.762466, Training Accuracy= 0.96875
# Iter 203520, Minibatch Loss= 328.935608, Training Accuracy= 0.96094
# Iter 204800, Minibatch Loss= 3.685486, Training Accuracy= 0.99219
# Iter 206080, Minibatch Loss= 76.480705, Training Accuracy= 0.98438
# Iter 207360, Minibatch Loss= 93.309601, Training Accuracy= 0.97656
# Iter 208640, Minibatch Loss= 268.889832, Training Accuracy= 0.96875
# Iter 209920, Minibatch Loss= 61.232666, Training Accuracy= 0.97656
# Iter 211200, Minibatch Loss= 42.496803, Training Accuracy= 0.98438
# Iter 212480, Minibatch Loss= 35.255180, Training Accuracy= 0.99219
# Iter 213760, Minibatch Loss= 74.013191, Training Accuracy= 0.98438
# Iter 215040, Minibatch Loss= 307.519562, Training Accuracy= 0.94531
# Iter 216320, Minibatch Loss= 36.803665, Training Accuracy= 0.98438
# Iter 217600, Minibatch Loss= 16.613930, Training Accuracy= 0.99219
# Iter 218880, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 220160, Minibatch Loss= 119.779648, Training Accuracy= 0.96094
# Iter 221440, Minibatch Loss= 49.956207, Training Accuracy= 0.98438
# Iter 222720, Minibatch Loss= 9.391541, Training Accuracy= 0.99219
# Iter 224000, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 225280, Minibatch Loss= 133.056122, Training Accuracy= 0.97656
# Iter 226560, Minibatch Loss= 39.792366, Training Accuracy= 0.97656
# Iter 227840, Minibatch Loss= 150.800934, Training Accuracy= 0.98438
# Iter 229120, Minibatch Loss= 102.222115, Training Accuracy= 0.99219
# Iter 230400, Minibatch Loss= 157.150452, Training Accuracy= 0.96875
# Iter 231680, Minibatch Loss= 31.851334, Training Accuracy= 0.98438
# Iter 232960, Minibatch Loss= 21.058746, Training Accuracy= 0.99219
# Iter 234240, Minibatch Loss= 8.983051, Training Accuracy= 0.98438
# Iter 235520, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 236800, Minibatch Loss= 76.131897, Training Accuracy= 0.98438
# Iter 238080, Minibatch Loss= 130.422684, Training Accuracy= 0.99219
# Iter 239360, Minibatch Loss= 60.801407, Training Accuracy= 0.98438
# Iter 240640, Minibatch Loss= 164.590164, Training Accuracy= 0.95312
# Iter 241920, Minibatch Loss= 177.807907, Training Accuracy= 0.95312
# Iter 243200, Minibatch Loss= 74.958694, Training Accuracy= 0.99219
# Iter 244480, Minibatch Loss= 39.233246, Training Accuracy= 0.99219
# Iter 245760, Minibatch Loss= 8.313034, Training Accuracy= 0.99219
# Iter 247040, Minibatch Loss= 106.033600, Training Accuracy= 0.96875
# Iter 248320, Minibatch Loss= 40.214081, Training Accuracy= 0.97656
# Iter 249600, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 250880, Minibatch Loss= 79.605240, Training Accuracy= 0.99219
# Iter 252160, Minibatch Loss= 60.317947, Training Accuracy= 0.98438
# Iter 253440, Minibatch Loss= 5.004211, Training Accuracy= 0.99219
# Iter 254720, Minibatch Loss= 217.702866, Training Accuracy= 0.97656
# Iter 256000, Minibatch Loss= 63.237823, Training Accuracy= 0.97656
# Iter 257280, Minibatch Loss= 149.948822, Training Accuracy= 0.98438
# Iter 258560, Minibatch Loss= 25.570641, Training Accuracy= 0.99219
# Iter 259840, Minibatch Loss= 92.385658, Training Accuracy= 0.98438
# Iter 261120, Minibatch Loss= 25.245819, Training Accuracy= 0.97656
# Iter 262400, Minibatch Loss= 52.886009, Training Accuracy= 0.98438
# Iter 263680, Minibatch Loss= 60.285957, Training Accuracy= 0.98438
# Iter 264960, Minibatch Loss= 107.686363, Training Accuracy= 0.98438
# Iter 266240, Minibatch Loss= 137.047989, Training Accuracy= 0.96875
# Iter 267520, Minibatch Loss= 13.998642, Training Accuracy= 0.98438
# Iter 268800, Minibatch Loss= 83.503700, Training Accuracy= 0.97656
# Iter 270080, Minibatch Loss= 27.656548, Training Accuracy= 0.98438
# Iter 271360, Minibatch Loss= 72.268585, Training Accuracy= 0.97656
# Iter 272640, Minibatch Loss= 62.189682, Training Accuracy= 0.99219
# Iter 273920, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 275200, Minibatch Loss= 60.626125, Training Accuracy= 0.98438
# Iter 276480, Minibatch Loss= 11.640228, Training Accuracy= 0.99219
# Iter 277760, Minibatch Loss= 49.503281, Training Accuracy= 0.99219
# Iter 279040, Minibatch Loss= 95.799675, Training Accuracy= 0.96875
# Iter 280320, Minibatch Loss= 234.317810, Training Accuracy= 0.96875
# Iter 281600, Minibatch Loss= 180.226166, Training Accuracy= 0.96875
# Iter 282880, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 284160, Minibatch Loss= 125.748802, Training Accuracy= 0.97656
# Iter 285440, Minibatch Loss= 122.744720, Training Accuracy= 0.96875
# Iter 286720, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 288000, Minibatch Loss= 19.135040, Training Accuracy= 0.98438
# Iter 289280, Minibatch Loss= 66.796585, Training Accuracy= 0.98438
# Iter 290560, Minibatch Loss= 71.394501, Training Accuracy= 0.97656
# Iter 291840, Minibatch Loss= 34.136909, Training Accuracy= 0.98438
# Iter 293120, Minibatch Loss= 79.103424, Training Accuracy= 0.97656
# Iter 294400, Minibatch Loss= 76.867142, Training Accuracy= 0.97656
# Iter 295680, Minibatch Loss= 42.388268, Training Accuracy= 0.98438
# Iter 296960, Minibatch Loss= 33.431885, Training Accuracy= 0.99219
# Iter 298240, Minibatch Loss= 98.793228, Training Accuracy= 0.97656
# Iter 299520, Minibatch Loss= 3.086105, Training Accuracy= 0.99219
# Iter 300800, Minibatch Loss= 96.891701, Training Accuracy= 0.97656
# Iter 302080, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 303360, Minibatch Loss= 39.069851, Training Accuracy= 0.98438
# Iter 304640, Minibatch Loss= 19.622330, Training Accuracy= 0.97656
# Iter 305920, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 307200, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 308480, Minibatch Loss= 141.185333, Training Accuracy= 0.96875
# Iter 309760, Minibatch Loss= 27.839741, Training Accuracy= 0.96875
# Iter 311040, Minibatch Loss= 49.217216, Training Accuracy= 0.98438
# Iter 312320, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 313600, Minibatch Loss= 43.668900, Training Accuracy= 0.97656
# Iter 314880, Minibatch Loss= 155.027054, Training Accuracy= 0.95312
# Iter 316160, Minibatch Loss= 73.955650, Training Accuracy= 0.96875
# Iter 317440, Minibatch Loss= 84.483833, Training Accuracy= 0.96875
# Iter 318720, Minibatch Loss= 7.474255, Training Accuracy= 0.99219
# Iter 320000, Minibatch Loss= 99.795380, Training Accuracy= 0.98438
# Iter 321280, Minibatch Loss= 45.477333, Training Accuracy= 0.98438
# Iter 322560, Minibatch Loss= 150.820526, Training Accuracy= 0.97656
# Iter 323840, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 325120, Minibatch Loss= 43.007446, Training Accuracy= 0.99219
# Iter 326400, Minibatch Loss= 40.226067, Training Accuracy= 0.98438
# Iter 327680, Minibatch Loss= 52.786480, Training Accuracy= 0.96875
# Iter 328960, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 330240, Minibatch Loss= 20.702507, Training Accuracy= 0.97656
# Iter 331520, Minibatch Loss= 25.448105, Training Accuracy= 0.99219
# Iter 332800, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 334080, Minibatch Loss= 45.983994, Training Accuracy= 0.98438
# Iter 335360, Minibatch Loss= 18.262863, Training Accuracy= 0.98438
# Iter 336640, Minibatch Loss= 1.439087, Training Accuracy= 0.99219
# Iter 337920, Minibatch Loss= 85.591309, Training Accuracy= 0.96875
# Iter 339200, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 340480, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 341760, Minibatch Loss= 87.875534, Training Accuracy= 0.98438
# Iter 343040, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 344320, Minibatch Loss= 56.899666, Training Accuracy= 0.98438
# Iter 345600, Minibatch Loss= 72.725624, Training Accuracy= 0.98438
# Iter 346880, Minibatch Loss= 106.604279, Training Accuracy= 0.96875
# Iter 348160, Minibatch Loss= 1.638107, Training Accuracy= 0.99219
# Iter 349440, Minibatch Loss= 95.256104, Training Accuracy= 0.97656
# Iter 350720, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 352000, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 353280, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 354560, Minibatch Loss= 76.200455, Training Accuracy= 0.98438
# Iter 355840, Minibatch Loss= 126.958778, Training Accuracy= 0.96875
# Iter 357120, Minibatch Loss= 28.197353, Training Accuracy= 0.96875
# Iter 358400, Minibatch Loss= 49.531952, Training Accuracy= 0.99219
# Iter 359680, Minibatch Loss= 39.281773, Training Accuracy= 0.98438
# Iter 360960, Minibatch Loss= 3.067879, Training Accuracy= 0.99219
# Iter 362240, Minibatch Loss= 162.435211, Training Accuracy= 0.99219
# Iter 363520, Minibatch Loss= 30.241890, Training Accuracy= 0.99219
# Iter 364800, Minibatch Loss= 14.994118, Training Accuracy= 0.99219
# Iter 366080, Minibatch Loss= 11.861816, Training Accuracy= 0.98438
# Iter 367360, Minibatch Loss= 2.417557, Training Accuracy= 0.99219
# Iter 368640, Minibatch Loss= 82.371140, Training Accuracy= 0.98438
# Iter 369920, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 371200, Minibatch Loss= 34.317924, Training Accuracy= 0.99219
# Iter 372480, Minibatch Loss= 10.692520, Training Accuracy= 0.99219
# Iter 373760, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 375040, Minibatch Loss= 10.555336, Training Accuracy= 0.99219
# Iter 376320, Minibatch Loss= 30.806686, Training Accuracy= 0.99219
# Iter 377600, Minibatch Loss= 6.506073, Training Accuracy= 0.99219
# Iter 378880, Minibatch Loss= 23.608337, Training Accuracy= 0.99219
# Iter 380160, Minibatch Loss= 43.751751, Training Accuracy= 0.98438
# Iter 381440, Minibatch Loss= 94.114967, Training Accuracy= 0.96875
# Iter 382720, Minibatch Loss= 55.199715, Training Accuracy= 0.98438
# Optimization Finished!
# save model
# save model:./Test_MNIST_model.ckpt Finished
# Testing Accuracy: 0.992188

# %%
# encoding=utf-8
from __future__ import print_function
import tensorflow as tf
# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./MNIST_data", one_hot=True)

# Parameters
learning_rate = 0.001
training_iters = 128*10*300 
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')

# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)
pred_class_index=tf.argmax(pred, 1)

correct_pred = tf.equal(pred_class_index, tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

saver = tf.train.Saver()  ##保存的API
# Launch the graph
with tf.Session() as sess:
    #sess.run(init) #不使用训练好的参数
    load_path = saver.restore(sess,"./Test_MNIST_model.ckpt")  #load上一步训练的参数
    step = 1
    # Keep training until reach max iterations
    batch_x=mnist.test.images[:256]
    batch_y=mnist.test.labels[:256]
    print ("batch_y:",batch_y)
    # Calculate batch loss and accuracy
    pred_value = sess.run([pred_class_index], feed_dict={x: batch_x, y: batch_y,keep_prob: 1.})
    print("pred_value:",pred_value)
    # Calculate accuracy for 256 mnist test images
    # mnist部分测试数据集，用刚刚训练好的模型来做预测。
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.}))
# Out:
# Extracting ./MNIST_data/train-images-idx3-ubyte.gz
# Extracting ./MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ./MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ./MNIST_data/t10k-labels-idx1-ubyte.gz
# INFO:tensorflow:Restoring parameters from ./Test_MNIST_model.ckpt
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# NotFoundError: Key Variable_31 not found in checkpoint
# 	 [[Node: save_3/RestoreV2_49 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_3/Const_0_0, save_3/RestoreV2_49/tensor_names, save_3/RestoreV2_49/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-10-561077b5e9ee> in <module>()
#      94 with tf.Session() as sess:
#      95     #sess.run(init) #不使用训练好的参数
# ---> 96     load_path = saver.restore(sess,"./Test_MNIST_model.ckpt")  #load上一步训练的参数
#      97     step = 1
#      98     # Keep training until reach max iterations
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1664     if context.in_graph_mode():
#    1665       sess.run(self.saver_def.restore_op_name,
# -> 1666                {self.saver_def.filename_tensor_name: save_path})
#    1667     else:
#    1668       self._build_eager(save_path, build_save=False, build_restore=True)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1334         except KeyError:
#    1335           pass
# -> 1336       raise type(e)(node_def, op, message)
#    1337
#    1338   def _extend_graph(self):
#
# NotFoundError: Key Variable_31 not found in checkpoint
# 	 [[Node: save_3/RestoreV2_49 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_3/Const_0_0, save_3/RestoreV2_49/tensor_names, save_3/RestoreV2_49/shape_and_slices)]]
#
# Caused by op 'save_3/RestoreV2_49', defined at:
#   File "/usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/usr/local/lib/python3.6/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-561077b5e9ee>", line 92, in <module>
#     saver = tf.train.Saver()  ##保存的API
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1218, in __init__
#     self.build()
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1227, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1263, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 751, in _build_internal
#     restore_sequentially, reshape)
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 427, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 267, in restore_op
#     [spec.tensor.dtype])[0])
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1021, in restore_v2
#     shape_and_slices=shape_and_slices, dtypes=dtypes, name=name)
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2956, in create_op
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1470, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# NotFoundError (see above for traceback): Key Variable_31 not found in checkpoint
# 	 [[Node: save_3/RestoreV2_49 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_3/Const_0_0, save_3/RestoreV2_49/tensor_names, save_3/RestoreV2_49/shape_and_slices)]]
